# %%
print("송은이")
# Out:
# 송은이

# %%
print(1)
# Out:
# 1

# %%
if 5>2:
  print("True")
# Out:
# True

# %%
# 나누기랑 나머지 차이

# 나누기
40 /2
print(40/2)
#나머지
print(40%2)
# Out:
# 20.0
# 0

# %%
32/3
# Out:
# 10.666666666666666

# %%
32//3
# Out:
# 10

# %%
apple = 120
banana = 100

not( apple == 120 and banana > 120)
# Out:
# True

# %%
# 여러 변수를 한번에
x,y,z = 1,2,3

print(x,y,z)
# Out:
# 1 2 3

# %%
fruits = [ 2023, "넷플","농"]
x,y,z = fruits
x
# Out:
# 2023

# %%
# 따옴표 중복 사용법
print("환영'환영'")
print('환영"환영"')
# 큰, 작은을 섞어써야함
# 동일한 따옴표 쓰고싶으면 \ 사용해야함
print("환영\"환영\"")
# Out:
# 환영'환영'
# 환영"환영"
# 환영"환영"

# %%
# \t : 탭키
print("환\t영")

# \n : 새로운 줄
print("환\n영")

# \r : 순서바꿈
print("환\r영")

# \b : 앞글자삭제
print("환\b영")
# Out:
# 환	영
# 환
# 영
# 영
# 영

# %%
print('''안녕''')
# Out:
# 안녕

# %%
print(2e3)
print(.2e3)
print(2e-3)
type(2e3)
# Out:
# 2000.0
# 200.0
# 0.002
# float

# %%
import random
print(random.randint(1,500))
# Out:
# 149

# %%
# 리스트 순서 뒤집기
animal = [1,2,3]
print(animal[::-1])
# Out:
# [3, 2, 1]

# %%
animal*2
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
# 리스트 두개 합치기

a=[1,2,3]
b=[4,5,6]
c = a+b
print(c)
a.extend(b)
a
# extend 는 다른 변수에 지정 안됨
# d = a.extend(b) 불가능. a에 바로 덮여짐
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6]

# %%
# 3.17 딕셔너리 이전까지 진도 나감
