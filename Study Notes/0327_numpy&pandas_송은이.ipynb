# %%
import pandas as pd
import numpy as np

# %%
before = np.array([1,2,3,4,5,6])

after = before.reshape(2,3)
after
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
after_reshape = after.transpose()
after_reshape
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
# !pip install --upgrade pandas # 버전 업데이트하기
pd.__version__
# 판다스 cheatsheet 공부
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 64.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.4.4
#     Uninstalling pandas-1.4.4:
#       Successfully uninstalled pandas-1.4.4
# ...
# '1.4.4'

# %%
# !pip install pydataset #매번 설치 필요
from pydataset import data #데이터셋 패키지
data('Housing', show_doc=True) #Housing 데이터 설명
house = data('Housing') #Housing 데이터를 house에 할당
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 34.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939433 sha256=4a99f87e08205f00c151ce7430d2569c5433006fdb28f9f9539ea6e919ddfede
#   Stored in directory: /root/.cache/pip/wheels/6b/86/a7/f71cb84c7bff804d83e293615a20c0531234397b796aee2645
# Successfully built pydataset
# ...
# initiated datasets repo at: /root/.pydataset/
# Housing
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Sales Prices of Houses in the City of Windsor
#
# ### Description
#
# a cross-section from 1987
#
# _number of observations_ : 546
#
# _observation_ : goods
#
# _country_ : Canada
#
# ### Usage
#
#     data(Housing)
#
# ### Format
#
# A dataframe containing :
#
# price
#
# sale price of a house
#
# lotsize
#
# ...

# %%
# 딕셔너리를 데이터 프레임으로 만드는 코드
# df = pd.DataFrame(dict)
# -> key : 칼럼 value : 행, index 는 list 형태로 따로 지정해줘야함

# %%
# 칼럼을 로우로 # 피벗을 푼다
# pd.melt(df)

# %%
# 칼럼 중심으로 데이터프레임 합치기 
# pd.concat([df1,df2])

# %%
# 피벗테이블

house.pivot_table(columns=['bedrooms'], aggfunc='size') 

#특정 칼럼내 값 개수
# Out:
# bedrooms
# 1      2
# 2    136
# 3    301
# 4     95
# 5     10
# 6      2
# dtype: int64

# %%
house.columns
# Out:
# Index(['price', 'lotsize', 'bedrooms', 'bathrms', 'stories', 'driveway',
#        'recroom', 'fullbase', 'gashw', 'airco', 'garagepl', 'prefarea'],
#       dtype='object')

# %%
house.loc[:,'price':'bedrooms']
# 끝 값 포함 -> 이상, 이하
# Out:
#         price  lotsize  bedrooms
# 1     42000.0     5850         3
# 2     38500.0     4000         2
# 3     49500.0     3060         3
# 4     60500.0     6650         3
# 5     61000.0     6360         2
# ..        ...      ...       ...
# 542   91500.0     4800         3
# 543   94000.0     6000         3
# 544  103000.0     6000         3
# 545  105000.0     6000         3
# 546  105000.0     6000         3
#
# [546 rows x 3 columns]

# %%
house.iloc[:,0:2]
# 끝값 미포함 -> 이상, 미만
# Out:
#         price  lotsize
# 1     42000.0     5850
# 2     38500.0     4000
# 3     49500.0     3060
# 4     60500.0     6650
# 5     61000.0     6360
# ..        ...      ...
# 542   91500.0     4800
# 543   94000.0     6000
# 544  103000.0     6000
# 545  105000.0     6000
# 546  105000.0     6000
#
# [546 rows x 2 columns]

# %%
pd.isna(house)
# Out:
#      price  lotsize  bedrooms  bathrms  stories  driveway  recroom  fullbase  \
# 1    False    False     False    False    False     False    False     False
# 2    False    False     False    False    False     False    False     False
# 3    False    False     False    False    False     False    False     False
# 4    False    False     False    False    False     False    False     False
# 5    False    False     False    False    False     False    False     False
# ..     ...      ...       ...      ...      ...       ...      ...       ...
# 542  False    False     False    False    False     False    False     False
# 543  False    False     False    False    False     False    False     False
# 544  False    False     False    False    False     False    False     False
# 545  False    False     False    False    False     False    False     False
# 546  False    False     False    False    False     False    False     False
#
#      gashw  airco  garagepl  prefarea
# ...

# %%
house.dtypes # 타입 보기
# Out:
# price       float64
# lotsize       int64
# bedrooms      int64
# bathrms       int64
# stories       int64
# driveway     object
# recroom      object
# fullbase     object
# gashw        object
# airco        object
# garagepl      int64
# prefarea     object
# dtype: object

# %%
house.info() # null 값 보기 좋다
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 546 entries, 1 to 546
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   price     546 non-null    float64
#  1   lotsize   546 non-null    int64
#  2   bedrooms  546 non-null    int64
#  3   bathrms   546 non-null    int64
#  4   stories   546 non-null    int64
#  5   driveway  546 non-null    object
#  6   recroom   546 non-null    object
#  7   fullbase  546 non-null    object
#  8   gashw     546 non-null    object
#  9   airco     546 non-null    object
#  10  garagepl  546 non-null    int64
#  11  prefarea  546 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 55.5+ KB

# %%
house['bedrooms'].value_counts()
# Out:
# 3    301
# 2    136
# 4     95
# 5     10
# 1      2
# 6      2
# Name: bedrooms, dtype: int64

# %%
# 그룹화
# mean, max, sum, 등등
house.groupby("recroom").mean()
house.groupby(["recroom","driveway"]).sum()
# Out:
#                        price  lotsize  bedrooms  bathrms  stories  garagepl
# recroom driveway
# no      no         3339295.0   254213       211       84      108        17
#         yes       25827797.0  1994819      1108      480      696       287
# yes     no          399500.0    23483        19       11       11         3
#         yes        7627800.0   539530       281      127      172        71
